# %%
# !ls
# Out:
# drive  sample_data

# %%
# !python3 /content/drive/MyDrive/MLOPs\ Assignment/MLOPs WorkFlows/scripts/data.py
# Out:
# python3: can't open file '/content/drive/MyDrive/MLOPs Assignment/MLOPs': [Errno 2] No such file or directory

# %%
# !zip -r "/content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows.zip" "/content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows"
# Out:
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/ (stored 0%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/requirements.txt (deflated 14%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/.gitignore (deflated 18%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/README.md (deflated 50%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/data/ (stored 0%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/data/genre_reviews_dict.pickle (deflated 60%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/data/.ipynb_checkpoints/ (stored 0%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/scripts/ (stored 0%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/scripts/utils.py (deflated 55%)
#   adding: content/drive/MyDrive/MLOPs Assignment/MLOPs WorkFlows/scripts/data.py (deflated 69%)
# ...
